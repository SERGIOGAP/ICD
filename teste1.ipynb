# %% [markdown]
# <a href="https://colab.research.google.com/github/SERGIOGAP/ICD/blob/main/teste1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i=2

# %%
i=2
j=3
k=i+j
print(k)
# Out:
# 5
